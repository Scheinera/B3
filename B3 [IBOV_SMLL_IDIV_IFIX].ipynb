# %% [markdown]
# ## Bibliotecas

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
from datetime import datetime
import plotly.graph_objects as go
import numpy as np

# %%
from IPython import get_ipython

ipython = get_ipython()

ipython.magic('pip install google-colab')

# %% [markdown]
# ## Ibov + YFinance

# %%
def get_tickers(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return (pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1].index + '.SA').to_list()

t = get_tickers('IBOV')

ibov = yf.download(t, period='5y', interval='1mo')['Adj Close']

ibov.columns  = ibov.columns.str.rstrip('.SA')
ibov.dropna(how='all', inplace=True)

ibov.fillna(value=0, inplace=True)

ibov.head(3)
# Out:
# [*********************100%%**********************]  82 of 82 completed
# 10 Failed downloads:
# ['VVAR3.SA', 'BRML3.SA', 'LAME4.SA', 'GNDI3.SA', 'HGTX3.SA', 'BTOW3.SA', 'LCAM3.SA', 'SULA11.SA', 'BRDT3.SA', 'IGTA3.SA']: Exception('%ticker%: No data found, symbol may be delisted')
#                          ABEV3  ASAI3      AZUL4     B3SA3      BBAS3  \
# Date
# 2018-10-01 00:00:00  13.830125    0.0  30.590000  7.308738  30.737375
# 2018-11-01 00:00:00  14.321035    0.0  34.740002  7.765879  32.089108
# 2018-12-01 00:00:00  13.017585    0.0  36.000000  7.383090  33.746193
#
#                          BBDC3      BBDC4      BBSE3     BEEF3    BPAC11  ...  \
# Date                                                                      ...
# 2018-10-01 00:00:00  14.865230  16.598831  17.118729  4.274224  4.398983  ...
# 2018-11-01 00:00:00  16.517708  18.624449  18.308249  4.289795  4.928553  ...
# 2018-12-01 00:00:00  16.654577  18.726259  17.836323  3.884951  5.240063  ...
#
#                         TAEE11     TIMS3     TOTS3      UGPA3     USIM5  \
# Date
# 2018-10-01 00:00:00  13.716608  9.436833  7.965058  19.931465  8.368706
# 2018-11-01 00:00:00  13.852174  9.656673  9.202657  21.282755  7.611615
# 2018-12-01 00:00:00  15.009733  9.648529  8.615591  23.962803  7.505784
#
#                          VALE3      VIVT3  VVAR3     WEGE3      YDUQ3
# Date
# 2018-10-01 00:00:00  39.067673  27.054108    0.0  8.393476  20.261892
# 2018-11-01 00:00:00  36.374062  30.009251    0.0  8.309543  21.681013
# 2018-12-01 00:00:00  35.134041  28.642677    0.0  8.178976  22.091749
#
# [3 rows x 82 columns]

# %% [markdown]
# ## Small + YFinance

# %%
def get_tickers1(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return (pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1].index + '.SA').to_list()

u = get_tickers1('SMLL')

smll = yf.download(u, period='5y', interval='1mo')['Adj Close']

smll.columns  = smll.columns.str.rstrip('.SA')
smll.dropna(how='all', inplace=True)

smll.fillna(value=0, inplace=True)
smll.head(3)
# Out:
# [*********************100%%**********************]  101 of 101 completed
# 18 Failed downloads:
# ['PARD3.SA', 'BRML3.SA', 'OMGE3.SA', 'DTEX3.SA', 'CCPR3.SA', 'DMMO3.SA', 'TIET11.SA', 'SMLS3.SA', 'LINX3.SA', 'HGTX3.SA', 'WIZS3.SA', 'LCAM3.SA', 'RLOG3.SA', 'BKBR3.SA', 'CNTO3.SA', 'IGTA3.SA', 'JPSA3.SA', 'CESP6.SA']: Exception('%ticker%: No data found, symbol may be delisted')
#                          AALR3      ABCB4      ALSO3     ALUP11  AMAR3  \
# Date
# 2018-10-01 00:00:00  11.859594  11.870805  21.371235  13.786975   5.20
# 2018-11-01 00:00:00  12.938641  12.091043  22.814608  14.417236   5.65
# 2018-12-01 00:00:00  13.176229  12.392036  23.997242  14.440873   5.19
#
#                         ANIM3      ARZZ3      AZUL4     BEEF3  BKBR3  ...  \
# Date                                                                  ...
# 2018-10-01 00:00:00  5.548049  43.218605  30.590000  4.274225    0.0  ...
# 2018-11-01 00:00:00  5.608028  45.811367  34.740002  4.289796    0.0  ...
# 2018-12-01 00:00:00  5.664674  50.508083  36.000000  3.884951    0.0  ...
#
#                      TIET11     TRIS3      TUPY3      UNIP6     USIM5  VIVA3  \
# Date
# 2018-10-01 00:00:00     0.0  2.373975  14.955041  20.760208  8.368705    0.0
# 2018-11-01 00:00:00     0.0  2.750537  16.860743  19.217575  7.611615    0.0
# 2018-12-01 00:00:00     0.0  3.356309  17.533321  19.804100  7.505784    0.0
#
#                          VLID3     VULC3  WIZS3      YDUQ3
# Date
# 2018-10-01 00:00:00  12.863969  5.486650    0.0  20.261892
# 2018-11-01 00:00:00  14.408658  5.583369    0.0  21.681015
# 2018-12-01 00:00:00  15.193664  6.242823    0.0  22.091751
#
# [3 rows x 101 columns]

# %% [markdown]
# ## Idiv + YFinance

# %%
def get_tickers2(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return (pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1].index + '.SA').to_list()

v = get_tickers2('idiv')

idiv = yf.download(v, period='5y', interval='1mo')['Adj Close']

idiv.columns  = idiv.columns.str.rstrip('.SA')
idiv.dropna(how='all', inplace=True)

idiv.fillna(value=0, inplace=True)
idiv.head(3)
# Out:
# [*********************100%%**********************]  39 of 39 completed
# 4 Failed downloads:
# ['BRDT3.SA', 'SMLS3.SA', 'WIZS3.SA', 'TIET11.SA']: Exception('%ticker%: No data found, symbol may be delisted')
#                          ABCB4      BBAS3      BBSE3      BRAP4  BRDT3  \
# Date
# 2018-10-01 00:00:00  11.870805  30.737383  17.118731  17.280657    0.0
# 2018-11-01 00:00:00  12.091043  32.089111  18.308252  15.890606    0.0
# 2018-12-01 00:00:00  12.392036  33.746201  17.836321  15.845603    0.0
#
#                          BRSR6      CCRO3     CIEL3     CMIG4     CPLE3  ...  \
# Date                                                                     ...
# 2018-10-01 00:00:00  13.664563   9.247276  9.564177  4.737638  1.831449  ...
# 2018-11-01 00:00:00  15.156638  11.364889  6.897799  5.459239  2.218018  ...
# 2018-12-01 00:00:00  15.399645   9.798828  6.441328  5.953189  2.098315  ...
#
#                         SAPR4      SLCE3  SMLS3     TAEE11      TGMA3  TIET11  \
# Date
# 2018-10-01 00:00:00  2.474478  18.083899    0.0  13.716610  17.803356     0.0
# 2018-11-01 00:00:00  2.565307  14.709798    0.0  13.852173  18.593586     0.0
# 2018-12-01 00:00:00  2.626678  13.261947    0.0  15.009735  21.513119     0.0
#
#                          TRPL4      UNIP6      VIVT3  WIZS3
# Date
# 2018-10-01 00:00:00  10.586164  20.760210  27.054113    0.0
# 2018-11-01 00:00:00  11.687705  19.217571  30.009256    0.0
# 2018-12-01 00:00:00  11.206590  19.804104  28.642670    0.0
#
# [3 rows x 39 columns]

# %% [markdown]
# ## Ifix (Fdo Imob) + YFinance

# %%
def get_tickers3(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return (pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1].index + '.SA').to_list()

w = get_tickers3('ifix')

ifix = yf.download(w, period='5y', interval='1mo')['Adj Close']

ifix.columns  = ifix.columns.str.rstrip('.SA')
ifix.dropna(how='all', inplace=True)

ifix.fillna(value=0, inplace=True)

ifix.head(3)
# Out:
# [*********************100%%**********************]  87 of 87 completed
#                ABCP11     ALZR11  BARI11      BBFI11B      BBPO11     BCFF11  \
# Date
# 2018-10-01  73.023392  78.453865     0.0  1573.490356  114.713333   0.000000
# 2018-11-01  73.463295  81.156219     0.0  1807.386108  115.802299   0.000000
# 2018-12-01  76.102692  84.662445     0.0  1760.589722  116.276138  82.614441
#
#                BCIA11     BCRI11     BPFF11  BRCO11  ...     VISC11  \
# Date                                                 ...
# 2018-10-01  89.795990  91.091629  76.850342     0.0  ...  88.868248
# 2018-11-01  89.086197  89.745316  75.294945     0.0  ...  91.757500
# 2018-12-01  89.505234  91.415733  76.014099     0.0  ...  94.271393
#
#                VRTA11     VTLT11  XPCI11     XPCM11  XPIN11  XPLG11  XPML11  \
# Date
# 2018-10-01  93.934540  86.580818     0.0  79.536972     0.0     0.0     0.0
# 2018-11-01  94.769516  85.400955     0.0  80.694031     0.0     0.0     0.0
# 2018-12-01  99.779343  85.273628     0.0  81.431114     0.0     0.0     0.0
#
#             XPPR11  XPSF11
# Date
# 2018-10-01     0.0     0.0
# 2018-11-01     0.0     0.0
# 2018-12-01     0.0     0.0
#
# [3 rows x 87 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e7d97914-060e-41f3-8a33-20fce07d5e84' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
